# %% [markdown]
# this is for dummy user creation

# %%
import random

# %%
moods = ["happy", "sad", "calm", "angry"]
budgets = ["high", "medium", "low", "random"]
cities = ["jakarta", "bandung", "semarang", "jogja", "surabaya","random"]
distances = ["high", "medium", "low", "random"]

# %%
users = {}

# %%
n = 300
for i in range(n):
    preferences = {}
    preferences["mood"] = random.choice(moods)
    preferences["budget"] = random.choice(budgets)
    preferences["city"] = random.choice(cities)
    preferences["distance"] = random.choice(distances)
    users[f"{i}"] =  preferences
print(users)
# Out:
# {'0': {'mood': 'angry', 'budget': 'medium', 'city': 'bandung', 'distance': 'low'}, '1': {'mood': 'angry', 'budget': 'high', 'city': 'bandung', 'distance': 'low'}, '2': {'mood': 'happy', 'budget': 'medium', 'city': 'jogja', 'distance': 'high'}, '3': {'mood': 'sad', 'budget': 'medium', 'city': 'jakarta', 'distance': 'random'}, '4': {'mood': 'sad', 'budget': 'high', 'city': 'random', 'distance': 'high'}, '5': {'mood': 'sad', 'budget': 'random', 'city': 'jakarta', 'distance': 'medium'}, '6': {'mood': 'calm', 'budget': 'high', 'city': 'semarang', 'distance': 'medium'}, '7': {'mood': 'calm', 'budget': 'medium', 'city': 'random', 'distance': 'random'}, '8': {'mood': 'sad', 'budget': 'high', 'city': 'jogja', 'distance': 'medium'}, '9': {'mood': 'calm', 'budget': 'low', 'city': 'jakarta', 'distance': 'random'}, '10': {'mood': 'happy', 'budget': 'random', 'city': 'surabaya', 'distance': 'random'}, '11': {'mood': 'happy', 'budget': 'medium', 'city': 'jakarta', 'distance': 'medium'}, '12': {'mood': 'happy', 'budget': 'low', 'city': 'bandung', 'distance': 'high'}, '13': {'mood': 'happy', 'budget': 'medium', 'city': 'semarang', 'distance': 'low'}, '14': {'mood': 'happy', 'budget': 'low', 'city': 'semarang', 'distance': 'random'}, '15': {'mood': 'calm', 'budget': 'medium', 'city': 'random', 'distance': 'medium'}, '16': {'mood': 'angry', 'budget': 'random', 'city': 'semarang', 'distance': 'medium'}, '17': {'mood': 'sad', 'budget': 'medium', 'city': 'jakarta', 'distance': 'random'}, '18': {'mood': 'sad', 'budget': 'high', 'city': 'surabaya', 'distance': 'medium'}, '19': {'mood': 'happy', 'budget': 'random', 'city': 'surabaya', 'distance': 'random'}, '20': {'mood': 'calm', 'budget': 'low', 'city': 'semarang', 'distance': 'medium'}, '21': {'mood': 'calm', 'budget': 'low', 'city': 'jakarta', 'distance': 'high'}, '22': {'mood': 'sad', 'budget': 'medium', 'city': 'jogja', 'distance': 'low'}, '23': {'mood': 'happy', 'budget': 'random', 'city': 'random', 'distance': 'high'}, '24': {'mood': 'happy', 'budget': 'low', 'city': 'random', 'distance': 'high'}, '25': {'mood': 'sad', 'budget': 'high', 'city': 'surabaya', 'distance': 'low'}, '26': {'mood': 'sad', 'budget': 'medium', 'city': 'jogja', 'distance': 'low'}, '27': {'mood': 'calm', 'budget': 'low', 'city': 'jakarta', 'distance': 'low'}, '28': {'mood': 'angry', 'budget': 'high', 'city': 'bandung', 'distance': 'low'}, '29': {'mood': 'angry', 'budget': 'random', 'city': 'jogja', 'distance': 'low'}, '30': {'mood': 'happy', 'budget': 'medium', 'city': 'semarang', 'distance': 'medium'}, '31': {'mood': 'calm', 'budget': 'medium', 'city': 'random', 'distance': 'medium'}, '32': {'mood': 'happy', 'budget': 'random', 'city': 'semarang', 'distance': 'random'}, '33': {'mood': 'angry', 'budget': 'medium', 'city': 'jogja', 'distance': 'high'}, '34': {'mood': 'happy', 'budget': 'low', 'city': 'random', 'distance': 'high'}, '35': {'mood': 'happy', 'budget': 'high', 'city': 'bandung', 'distance': 'low'}, '36': {'mood': 'calm', 'budget': 'medium', 'city': 'random', 'distance': 'low'}, '37': {'mood': 'happy', 'budget': 'medium', 'city': 'semarang', 'distance': 'high'}, '38': {'mood': 'happy', 'budget': 'random', 'city': 'semarang', 'distance': 'random'}, '39': {'mood': 'calm', 'budget': 'random', 'city': 'surabaya', 'distance': 'medium'}, '40': {'mood': 'happy', 'budget': 'low', 'city': 'jogja', 'distance': 'low'}, '41': {'mood': 'sad', 'budget': 'medium', 'city': 'surabaya', 'distance': 'low'}, '42': {'mood': 'sad', 'budget': 'random', 'city': 'jogja', 'distance': 'high'}, '43': {'mood': 'happy', 'budget': 'random', 'city': 'random', 'distance': 'random'}, '44': {'mood': 'sad', 'budget': 'medium', 'city': 'random', 'distance': 'high'}, '45': {'mood': 'sad', 'budget': 'random', 'city': 'surabaya', 'distance': 'high'}, '46': {'mood': 'happy', 'budget': 'low', 'city': 'surabaya', 'distance': 'medium'}, '47': {'mood': 'angry', 'budget': 'low', 'city': 'jogja', 'distance': 'low'}, '48': {'mood': 'calm', 'budget': 'medium',  ...
